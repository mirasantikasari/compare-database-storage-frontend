# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook demonstrates how to train custom openWakeWord models using pre-defined datasets and an automated process for dataset generation and training. While not guaranteed to always produce the best performing model, the methods shown in this notebook often produce baseline models with releatively strong performance.
#
# Manual data preparation and model training (e.g., see the [training models](training_models.ipynb) notebook) remains an option for when full control over the model development process is needed.
#
# At a high level, the automatic training process takes advantages of several techniques to try and produce a good model, including:
#
# - Early-stopping and checkpoint averaging (similar to [stochastic weight averaging](https://arxiv.org/abs/1803.05407)) to search for the best models found during training, according to the validation data
# - Variable learning rates with cosine decay and multiple cycles
# - Adaptive batch construction to focus on only high-loss examples when the model begins to converge, combined with gradient accumulation to ensure that batch sizes are still large enough for stable training
# - Cycical weight schedules for negative examples to help the model reduce false-positive rates
#
# See the contents of the `train.py` file for more details.

# %% [markdown]
# # Environment Setup

# %% [markdown]
# To begin, we'll need to install the requirements for training custom models. In particular, a relatively recent version of Pytorch and custom fork of the [piper-sample-generator](https://github.com/dscripka/piper-sample-generator) library for generating synthetic examples for the custom model.
#
# **Important Note!** Currently, automated model training is only supported on linux systems due to the requirements of the text to speech library used for synthetic sample generation (Piper). It may be possible to use Piper on Windows/Mac systems, but that has not (yet) been tested.

# %%
## Environment setup

# install piper-sample-generator (currently only supports linux systems)
# !git clone https://github.com/rhasspy/piper-sample-generator
# !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'
# !pip install piper-phonemize
# !pip install webrtcvad

# install openwakeword (full installation to support training)
# !git clone https://github.com/dscripka/openwakeword
# !pip install -e ./openwakeword
# !cd openwakeword

# install other dependencies
# !pip install mutagen==1.47.0
# !pip install torchinfo==1.8.0
# !pip install torchmetrics==1.2.0
# !pip install speechbrain==0.5.14
# !pip install audiomentations==0.33.0
# !pip install torch-audiomentations==0.11.0
# !pip install acoustics==0.2.6
# !pip install tensorflow-cpu==2.8.1
# !pip install tensorflow_probability==0.16.0
# !pip install onnx_tf==1.10.0
# !pip install pronouncing==0.2.0
# !pip install datasets==2.14.6
# !pip install deep-phonemizer==0.0.19

# Download required models (workaround for Colab)
import os
os.makedirs("./openwakeword/openwakeword/resources/models", exist_ok=True)
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx -O ./openwakeword/openwakeword/resources/models/embedding_model.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite -O ./openwakeword/openwakeword/resources/models/embedding_model.tflite
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.onnx -O ./openwakeword/openwakeword/resources/models/melspectrogram.onnx
# !wget https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.tflite -O ./openwakeword/openwakeword/resources/models/melspectrogram.tflite
# Out:
# fatal: destination path 'piper-sample-generator' already exists and is not an empty directory.
# --2026-09-15 13:16:23--  https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/642029941/73f4af3c-7cf8-4547-a7b9-3bd29e7f3c33?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T14%3A07%3A39Z&rscd=attachment%3B+filename%3Den_US-libritts_r-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T13%3A07%3A29Z&ske=2026-09-15T14%3A07%3A39Z&sks=b&skv=2018-11-09&sig=ISc5hbEo9CZ5S4EFpAMu3KGX6gv9lMiLftu8XGNpSgc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ4MTc4MywibmJmIjoxNzg5NDc4MTgzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.quwFIaumbi582NfL8r7s8z2iPoOlht4Gfb5SgAj3Uo4&response-content-disposition=attachment%3B%20filename%3Den_US-libritts_r-medium.pt&response-content-type=application%2Foctet-stream [following]
# --2026-09-15 13:16:23--  https://release-assets.githubusercontent.com/github-production-release-asset/642029941/73f4af3c-7cf8-4547-a7b9-3bd29e7f3c33?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T14%3A07%3A39Z&rscd=attachment%3B+filename%3Den_US-libritts_r-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T13%3A07%3A29Z&ske=2026-09-15T14%3A07%3A39Z&sks=b&skv=2018-11-09&sig=ISc5hbEo9CZ5S4EFpAMu3KGX6gv9lMiLftu8XGNpSgc%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ4MTc4MywibmJmIjoxNzg5NDc4MTgzLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.quwFIaumbi582NfL8r7s8z2iPoOlht4Gfb5SgAj3Uo4&response-content-disposition=attachment%3B%20filename%3Den_US-libritts_r-medium.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 204089915 (195M) [application/octet-stream]
# Saving to: ‘piper-sample-generator/models/en_US-libritts_r-medium.pt’
#
# piper-sample-genera 100%[===================>] 194.63M   246MB/s    in 0.8s
#
# 2026-09-15 13:16:24 (246 MB/s) - ‘piper-sample-generator/models/en_US-libritts_r-medium.pt’ saved [204089915/204089915]
#
# ERROR: Could not find a version that satisfies the requirement piper-phonemize (from versions: none)
# ERROR: No matching distribution found for piper-phonemize
# Requirement already satisfied: webrtcvad in /usr/local/lib/python3.13/dist-packages (2.0.10)
# fatal: destination path 'openwakeword' already exists and is not an empty directory.
# Obtaining file:///content/openwakeword
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting onnxruntime<2,>=1.10.0 (from openwakeword==0.6.0)
#   Using cached onnxruntime-1.30.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (5.7 kB)
# Collecting ai-edge-litert<3,>=2.0.2 (from openwakeword==0.6.0)
#   Using cached ai_edge_litert-2.2.0-cp313-cp313-manylinux_2_27_x86_64.whl.metadata (2.3 kB)
# INFO: pip is looking at multiple versions of openwakeword to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement speexdsp-ns<1,>=0.1.2; platform_system == "Linux" (from openwakeword) (from versions: none)
# ERROR: No matching distribution found for speexdsp-ns<1,>=0.1.2; platform_system == "Linux"
# Requirement already satisfied: mutagen==1.47.0 in /usr/local/lib/python3.13/dist-packages (1.47.0)
# Requirement already satisfied: torchinfo==1.8.0 in /usr/local/lib/python3.13/dist-packages (1.8.0)
# Requirement already satisfied: torchmetrics==1.2.0 in /usr/local/lib/python3.13/dist-packages (1.2.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.13/dist-packages (from torchmetrics==1.2.0) (2.1.3)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.13/dist-packages (from torchmetrics==1.2.0) (2.11.0+cu128)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from torchmetrics==1.2.0) (0.15.3)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.13/dist-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (26.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.13/dist-packages (from lightning-utilities>=0.8.0->torchmetrics==1.2.0) (4.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.32.5)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (2023.10.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.8.1->torchmetrics==1.2.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.1->torchmetrics==1.2.0) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.1->torchmetrics==1.2.0) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.8.1->torchmetrics==1.2.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=1.8.1->torchmetrics==1.2.0) (3.0.3)
# Requirement already satisfied: speechbrain==0.5.14 in /usr/local/lib/python3.13/dist-packages (0.5.14)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (1.2.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (1.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (2.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (26.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (1.16.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (0.2.2)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (2.11.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (2.11.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (4.67.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.13/dist-packages (from speechbrain==0.5.14) (1.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (2023.10.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.9->speechbrain==0.5.14) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->speechbrain==0.5.14) (12.8.90)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub->speechbrain==0.5.14) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub->speechbrain==0.5.14) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub->speechbrain==0.5.14) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub->speechbrain==0.5.14) (6.0.3)
# Requirement already satisfied: ruamel.yaml<0.19.0,>=0.17.28 in /usr/local/lib/python3.13/dist-packages (from hyperpyyaml->speechbrain==0.5.14) (0.18.17)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib->speechbrain==0.5.14) (3.1.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.9->speechbrain==0.5.14) (1.8.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->speechbrain==0.5.14) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->speechbrain==0.5.14) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->speechbrain==0.5.14) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->speechbrain==0.5.14) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->speechbrain==0.5.14) (0.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.15 in /usr/local/lib/python3.13/dist-packages (from ruamel.yaml<0.19.0,>=0.17.28->hyperpyyaml->speechbrain==0.5.14) (0.2.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.9->speechbrain==0.5.14) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=1.9->speechbrain==0.5.14) (3.0.3)
# Requirement already satisfied: audiomentations==0.33.0 in /usr/local/lib/python3.13/dist-packages (0.33.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.13/dist-packages (from audiomentations==0.33.0) (2.1.3)
# Requirement already satisfied: librosa!=0.10.0,<0.11.0,>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from audiomentations==0.33.0) (0.10.2.post1)
# Requirement already satisfied: scipy<2,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from audiomentations==0.33.0) (1.16.3)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /usr/local/lib/python3.13/dist-packages (from audiomentations==0.33.0) (0.5.0.post1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.1.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.6.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.61.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.14.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.9.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.16.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (1.2.2)
# Requirement already satisfied: standard-aifc in /usr/local/lib/python3.13/dist-packages (from audioread>=2.1.9->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.13.0)
# Requirement already satisfied: standard-sunau in /usr/local/lib/python3.13/dist-packages (from audioread>=2.1.9->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.13.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=0.14->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from lazy-loader>=0.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (26.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (4.11.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.13/dist-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=0.20.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.13/dist-packages (from soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.1.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (2026.7.22)
# Requirement already satisfied: standard-chunk in /usr/local/lib/python3.13/dist-packages (from standard-aifc->audioread>=2.1.9->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (3.13.0)
# Requirement already satisfied: audioop-lts in /usr/local/lib/python3.13/dist-packages (from standard-aifc->audioread>=2.1.9->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations==0.33.0) (0.2.2)
# Requirement already satisfied: torch-audiomentations==0.11.0 in /usr/local/lib/python3.13/dist-packages (0.11.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /usr/local/lib/python3.13/dist-packages (from torch-audiomentations==0.11.0) (0.2.8)
# Requirement already satisfied: librosa>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from torch-audiomentations==0.11.0) (0.10.2.post1)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from torch-audiomentations==0.11.0) (2.11.0+cu128)
# Requirement already satisfied: torchaudio>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from torch-audiomentations==0.11.0) (2.11.0+cu128)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /usr/local/lib/python3.13/dist-packages (from torch-audiomentations==0.11.0) (1.2.5)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (3.1.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (2.1.3)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.6.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.61.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.14.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (4.16.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.13/dist-packages (from librosa>=0.6.0->torch-audiomentations==0.11.0) (1.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.32.5)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (2023.10.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.7.0->torch-audiomentations==0.11.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.7.0->torch-audiomentations==0.11.0) (12.8.90)
# Requirement already satisfied: primePy>=1.3 in /usr/local/lib/python3.13/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations==0.11.0) (1.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.13/dist-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations==0.11.0) (26.3)
# Requirement already satisfied: standard-aifc in /usr/local/lib/python3.13/dist-packages (from audioread>=2.1.9->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.13.0)
# Requirement already satisfied: standard-sunau in /usr/local/lib/python3.13/dist-packages (from audioread>=2.1.9->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.13.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.7.0->torch-audiomentations==0.11.0) (1.8.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=0.14->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.1.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba>=0.51.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (4.11.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.13/dist-packages (from pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=0.20.0->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.13/dist-packages (from soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.7.0->torch-audiomentations==0.11.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=1.7.0->torch-audiomentations==0.11.0) (3.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.6.0->torch-audiomentations==0.11.0) (2026.7.22)
# Requirement already satisfied: standard-chunk in /usr/local/lib/python3.13/dist-packages (from standard-aifc->audioread>=2.1.9->librosa>=0.6.0->torch-audiomentations==0.11.0) (3.13.0)
# Requirement already satisfied: audioop-lts in /usr/local/lib/python3.13/dist-packages (from standard-aifc->audioread>=2.1.9->librosa>=0.6.0->torch-audiomentations==0.11.0) (0.2.2)
# Requirement already satisfied: acoustics==0.2.6 in /usr/local/lib/python3.13/dist-packages (0.2.6)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.13/dist-packages (from acoustics==0.2.6) (2.1.3)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.13/dist-packages (from acoustics==0.2.6) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from acoustics==0.2.6) (3.10.0)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from acoustics==0.2.6) (1.17.0)
# Requirement already satisfied: pandas>=0.15 in /usr/local/lib/python3.13/dist-packages (from acoustics==0.2.6) (2.2.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.13/dist-packages (from acoustics==0.2.6) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.15->acoustics==0.2.6) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.15->acoustics==0.2.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=0.15->acoustics==0.2.6) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->acoustics==0.2.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->acoustics==0.2.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->acoustics==0.2.6) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->acoustics==0.2.6) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->acoustics==0.2.6) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->acoustics==0.2.6) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->acoustics==0.2.6) (3.3.2)
# ERROR: Could not find a version that satisfies the requirement tensorflow-cpu==2.8.1 (from versions: 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow-cpu==2.8.1
# Requirement already satisfied: tensorflow_probability==0.16.0 in /usr/local/lib/python3.13/dist-packages (0.16.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.13/dist-packages (from tensorflow_probability==0.16.0) (1.4.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.13/dist-packages (from tensorflow_probability==0.16.0) (1.17.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from tensorflow_probability==0.16.0) (2.1.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from tensorflow_probability==0.16.0) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.13/dist-packages (from tensorflow_probability==0.16.0) (3.1.2)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.13/dist-packages (from tensorflow_probability==0.16.0) (0.7.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.13/dist-packages (from tensorflow_probability==0.16.0) (0.1.10)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.13/dist-packages (from dm-tree->tensorflow_probability==0.16.0) (26.1.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.13/dist-packages (from dm-tree->tensorflow_probability==0.16.0) (2.4.0)
# Collecting onnx_tf==1.10.0
#   Using cached onnx_tf-1.10.0-py3-none-any.whl.metadata (510 bytes)
# Collecting onnx>=1.10.2 (from onnx_tf==1.10.0)
#   Using cached onnx-1.22.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.13/dist-packages (from onnx_tf==1.10.0) (6.0.3)
# INFO: pip is looking at multiple versions of onnx-tf to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons (from onnx-tf) (from versions: none)
# ERROR: No matching distribution found for tensorflow-addons
# Requirement already satisfied: pronouncing==0.2.0 in /usr/local/lib/python3.13/dist-packages (0.2.0)
# Requirement already satisfied: cmudict>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from pronouncing==0.2.0) (1.1.3)
# Requirement already satisfied: importlib-metadata>=5 in /usr/local/lib/python3.13/dist-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (9.0.1)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.13/dist-packages (from cmudict>=0.4.0->pronouncing==0.2.0) (7.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.13/dist-packages (from importlib-metadata>=5->cmudict>=0.4.0->pronouncing==0.2.0) (4.1.0)
# Collecting datasets==2.14.6
#   Using cached datasets-2.14.6-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (2.1.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (23.0.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (4.0.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.14.6) (2023.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (3.14.3)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets==2.14.6)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from datasets==2.14.6) (6.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.14.6) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.14.6) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.14.6) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.14.6) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.14.6) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.14.6) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.14.6) (1.24.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (3.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (1.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.6) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->datasets==2.14.6) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->datasets==2.14.6) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->datasets==2.14.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->datasets==2.14.6) (2026.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets==2.14.6) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets==2.14.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets==2.14.6) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.14.6) (1.17.0)
# Using cached datasets-2.14.6-py3-none-any.whl (493 kB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Installing collected packages: huggingface-hub, datasets
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.31.0
#     Uninstalling huggingface_hub-1.31.0:
#       Successfully uninstalled huggingface_hub-1.31.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.19.0
#     Uninstalling datasets-2.19.0:
#       Successfully uninstalled datasets-2.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# diffusers 0.40.0 requires huggingface-hub<2.0,>=1.23.0, but you have huggingface-hub 0.36.2 which is incompatible.
# transformers 5.16.1 requires huggingface-hub<2.0,>=1.5.0, but you have huggingface-hub 0.36.2 which is incompatible.
# gradio 6.26.0 requires huggingface-hub<2.0,>=1.16.0, but you have huggingface-hub 0.36.2 which is incompatible.
# Successfully installed datasets-2.14.6 huggingface-hub-0.36.2
# Requirement already satisfied: deep-phonemizer==0.0.19 in /usr/local/lib/python3.13/dist-packages (0.0.19)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from deep-phonemizer==0.0.19) (2.11.0+cu128)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.13/dist-packages (from deep-phonemizer==0.0.19) (4.67.3)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.13/dist-packages (from deep-phonemizer==0.0.19) (6.0.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.13/dist-packages (from deep-phonemizer==0.0.19) (2.20.0)
# Requirement already satisfied: certifi>=2022.12.7 in /usr/local/lib/python3.13/dist-packages (from deep-phonemizer==0.0.19) (2026.7.22)
# Requirement already satisfied: wheel>=0.38.0 in /usr/local/lib/python3.13/dist-packages (from deep-phonemizer==0.0.19) (0.48.0)
# ...
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.2.0->deep-phonemizer==0.0.19) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.2.0->deep-phonemizer==0.0.19) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.2.0->deep-phonemizer==0.0.19) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.2.0->deep-phonemizer==0.0.19) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.2.0->deep-phonemizer==0.0.19) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.2.0->deep-phonemizer==0.0.19) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.2.0->deep-phonemizer==0.0.19) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.2.0->deep-phonemizer==0.0.19) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.2.0->deep-phonemizer==0.0.19) (12.8.90)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.13/dist-packages (from wheel>=0.38.0->deep-phonemizer==0.0.19) (26.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.13/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.13/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (1.83.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.13/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (3.10.3)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (2.1.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (11.3.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.13/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (5.29.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from tensorboard->deep-phonemizer==0.0.19) (3.1.8)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.2.0->deep-phonemizer==0.0.19) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.2.0->deep-phonemizer==0.0.19) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from werkzeug>=1.0.1->tensorboard->deep-phonemizer==0.0.19) (3.0.3)
# --2026-09-15 13:17:47--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.onnx
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/0233db07-b8db-4fc3-b026-b75d77fd7ae6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T13%3A52%3A39Z&rscd=attachment%3B+filename%3Dembedding_model.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T12%3A51%3A56Z&ske=2026-09-15T13%3A52%3A39Z&sks=b&skv=2018-11-09&sig=8BCPc7PSgO1SWldqaJX616yyEv9xHIi6shXQ%2Fb%2F6wtA%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ3ODU2NywibmJmIjoxNzg5NDc4MjY3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.gcTs1at1GSWNKCBT0GJxWYsUL_frg9tp5pw4Fh69Krg&response-content-disposition=attachment%3B%20filename%3Dembedding_model.onnx&response-content-type=application%2Foctet-stream [following]
# --2026-09-15 13:17:47--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/0233db07-b8db-4fc3-b026-b75d77fd7ae6?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T13%3A52%3A39Z&rscd=attachment%3B+filename%3Dembedding_model.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T12%3A51%3A56Z&ske=2026-09-15T13%3A52%3A39Z&sks=b&skv=2018-11-09&sig=8BCPc7PSgO1SWldqaJX616yyEv9xHIi6shXQ%2Fb%2F6wtA%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ3ODU2NywibmJmIjoxNzg5NDc4MjY3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.gcTs1at1GSWNKCBT0GJxWYsUL_frg9tp5pw4Fh69Krg&response-content-disposition=attachment%3B%20filename%3Dembedding_model.onnx&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1326578 (1.3M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/embedding_model.onnx’
#
# ./openwakeword/open 100%[===================>]   1.26M  --.-KB/s    in 0.04s
#
# 2026-09-15 13:17:47 (31.3 MB/s) - ‘./openwakeword/openwakeword/resources/models/embedding_model.onnx’ saved [1326578/1326578]
#
# --2026-09-15 13:17:47--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/embedding_model.tflite
# Resolving github.com (github.com)... 20.29.134.23
# Connecting to github.com (github.com)|20.29.134.23|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/4bfa8f05-dd30-45f6-b47c-c55548bb5ffc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T14%3A11%3A00Z&rscd=attachment%3B+filename%3Dembedding_model.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T13%3A10%3A37Z&ske=2026-09-15T14%3A11%3A00Z&sks=b&skv=2018-11-09&sig=oYuUP2%2BLZjkJoqIThcvk1RDEL8Dd%2Fe%2BQl4pYCVZM9D0%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ3ODU2NywibmJmIjoxNzg5NDc4MjY3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.gcTs1at1GSWNKCBT0GJxWYsUL_frg9tp5pw4Fh69Krg&response-content-disposition=attachment%3B%20filename%3Dembedding_model.tflite&response-content-type=application%2Foctet-stream [following]
# --2026-09-15 13:17:47--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/4bfa8f05-dd30-45f6-b47c-c55548bb5ffc?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T14%3A11%3A00Z&rscd=attachment%3B+filename%3Dembedding_model.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T13%3A10%3A37Z&ske=2026-09-15T14%3A11%3A00Z&sks=b&skv=2018-11-09&sig=oYuUP2%2BLZjkJoqIThcvk1RDEL8Dd%2Fe%2BQl4pYCVZM9D0%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ3ODU2NywibmJmIjoxNzg5NDc4MjY3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.gcTs1at1GSWNKCBT0GJxWYsUL_frg9tp5pw4Fh69Krg&response-content-disposition=attachment%3B%20filename%3Dembedding_model.tflite&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1330312 (1.3M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/embedding_model.tflite’
#
# ./openwakeword/open 100%[===================>]   1.27M  --.-KB/s    in 0.05s
#
# 2026-09-15 13:17:47 (28.0 MB/s) - ‘./openwakeword/openwakeword/resources/models/embedding_model.tflite’ saved [1330312/1330312]
#
# --2026-09-15 13:17:47--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.onnx
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/6b613c12-b693-4220-82d5-01be396893d9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T13%3A57%3A01Z&rscd=attachment%3B+filename%3Dmelspectrogram.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T12%3A56%3A21Z&ske=2026-09-15T13%3A57%3A01Z&sks=b&skv=2018-11-09&sig=bX3WEVnyMGD%2B0u2IvnmXdtfom1F%2B45C5PP4KcNJ5uwE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ3ODU2OCwibmJmIjoxNzg5NDc4MjY4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.7oGcF_fqedVkrjC2iwk_qoBDkOJLyiSHa3B2d9pfVsY&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.onnx&response-content-type=application%2Foctet-stream [following]
# --2026-09-15 13:17:48--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/6b613c12-b693-4220-82d5-01be396893d9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T13%3A57%3A01Z&rscd=attachment%3B+filename%3Dmelspectrogram.onnx&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T12%3A56%3A21Z&ske=2026-09-15T13%3A57%3A01Z&sks=b&skv=2018-11-09&sig=bX3WEVnyMGD%2B0u2IvnmXdtfom1F%2B45C5PP4KcNJ5uwE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ3ODU2OCwibmJmIjoxNzg5NDc4MjY4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.7oGcF_fqedVkrjC2iwk_qoBDkOJLyiSHa3B2d9pfVsY&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.onnx&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1087958 (1.0M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/melspectrogram.onnx’
#
# ./openwakeword/open 100%[===================>]   1.04M  --.-KB/s    in 0.03s
#
# 2026-09-15 13:17:48 (35.4 MB/s) - ‘./openwakeword/openwakeword/resources/models/melspectrogram.onnx’ saved [1087958/1087958]
#
# --2026-09-15 13:17:48--  https://github.com/dscripka/openWakeWord/releases/download/v0.5.1/melspectrogram.tflite
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/497407399/14a5e610-f7fa-4157-ae44-fdaabf875683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T13%3A54%3A02Z&rscd=attachment%3B+filename%3Dmelspectrogram.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T12%3A53%3A55Z&ske=2026-09-15T13%3A54%3A02Z&sks=b&skv=2018-11-09&sig=uc%2F6dGXXDLR5Ty06elVLPH%2BU5eblo4tLDiEKbo08JCE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ3ODU2OCwibmJmIjoxNzg5NDc4MjY4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.7oGcF_fqedVkrjC2iwk_qoBDkOJLyiSHa3B2d9pfVsY&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.tflite&response-content-type=application%2Foctet-stream [following]
# --2026-09-15 13:17:48--  https://release-assets.githubusercontent.com/github-production-release-asset/497407399/14a5e610-f7fa-4157-ae44-fdaabf875683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T13%3A54%3A02Z&rscd=attachment%3B+filename%3Dmelspectrogram.tflite&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T12%3A53%3A55Z&ske=2026-09-15T13%3A54%3A02Z&sks=b&skv=2018-11-09&sig=uc%2F6dGXXDLR5Ty06elVLPH%2BU5eblo4tLDiEKbo08JCE%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ3ODU2OCwibmJmIjoxNzg5NDc4MjY4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.7oGcF_fqedVkrjC2iwk_qoBDkOJLyiSHa3B2d9pfVsY&response-content-disposition=attachment%3B%20filename%3Dmelspectrogram.tflite&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1092516 (1.0M) [application/octet-stream]
# Saving to: ‘./openwakeword/openwakeword/resources/models/melspectrogram.tflite’
#
# ./openwakeword/open 100%[===================>]   1.04M  --.-KB/s    in 0.04s
#
# 2026-09-15 13:17:48 (29.2 MB/s) - ‘./openwakeword/openwakeword/resources/models/melspectrogram.tflite’ saved [1092516/1092516]

# %%
# !pip install -U "datasets==2.19.0" "huggingface_hub>=0.23.0"
# Out:
# Collecting datasets==2.19.0
#   Using cached datasets-2.19.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: huggingface_hub>=0.23.0 in /usr/local/lib/python3.13/dist-packages (0.36.2)
# Collecting huggingface_hub>=0.23.0
#   Using cached huggingface_hub-1.31.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (3.32.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (2.1.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (23.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (4.0.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (0.70.15)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets==2.19.0) (2023.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (3.14.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from datasets==2.19.0) (6.0.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.23.0) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.23.0) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.23.0) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.23.0) (4.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.19.0) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.19.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.19.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.19.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.19.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.19.0) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp->datasets==2.19.0) (1.24.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23.0) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23.0) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23.0) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.23.0) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->datasets==2.19.0) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->datasets==2.19.0) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets==2.19.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets==2.19.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets==2.19.0) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.19.0) (1.17.0)
# Using cached datasets-2.19.0-py3-none-any.whl (542 kB)
# Using cached huggingface_hub-1.31.0-py3-none-any.whl (798 kB)
# Installing collected packages: huggingface_hub, datasets
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 0.36.2
#     Uninstalling huggingface_hub-0.36.2:
#       Successfully uninstalled huggingface_hub-0.36.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.6
#     Uninstalling datasets-2.14.6:
#       Successfully uninstalled datasets-2.14.6
# Successfully installed datasets-2.19.0 huggingface_hub-1.31.0

# %%
# Imports

import os
import numpy as np
import torch
import sys
from pathlib import Path
import uuid
import yaml
import datasets
import scipy
from tqdm import tqdm

# %% [markdown]
# # Download Data

# %% [markdown]
# When training new openWakeWord models using the automated procedure, four specific types of data are required:
#
# 1) Synthetic examples of the target word/phrase generated with text-to-speech models
#
# 2) Synthetic examples of adversarial words/phrases generated with text-to-speech models
#
# 3) Room impulse reponses and noise/background audio data to augment the synthetic examples and make them more realistic
#
# 4) Generic "negative" audio data that is very unlikely to contain examples of the target word/phrase in the context where the model should detect it. This data can be the original audio data, or precomputed openWakeWord features ready for model training.
#
# 5) Validation data to use for early-stopping when training the model.
#
# For the purposes of this notebook, all five of these sources will either be generated manually or can be obtained from HuggingFace thanks to their excellent `datasets` library and extremely generous hosting policy. Also note that while only a portion of some datasets are downloaded, for the best possible performance it is recommended to download the entire dataset and keep a local copy for future training runs.

# %%
# Download room impulse responses collected by MIT
# https://mcdermottlab.mit.edu/Reverb/IR_Survey.html

output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
rir_dataset = datasets.load_dataset("davidscripka/MIT_environmental_impulse_responses", split="train", streaming=True)

# Save clips to 16-bit PCM wav files
for row in tqdm(rir_dataset):
    name = str(uuid.uuid4()) + ".wav"
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))
# Out:
# Downloading readme:   0%|          | 0.00/936 [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/270 [00:00<?, ?it/s]
# 270it [01:41,  2.65it/s]

# %%
## Download noise and background audio

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

fname = "bal_train09.tar"
out_dir = f"audioset/{fname}"
link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
# !wget -O {out_dir} {link}
# !cd audioset && tar -xvf bal_train09.tar

output_dir = "./audioset_16k"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

# Convert audioset files to 16khz sample rate
audioset_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("audioset/audio").glob("**/*.flac")]})
audioset_dataset = audioset_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
for row in tqdm(audioset_dataset):
    name = row['audio']['path'].split('/')[-1].replace(".flac", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# Free Music Archive dataset (https://github.com/mdeff/fma)
output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
fma_dataset = datasets.load_dataset("rudraml/fma", name="small", split="train", trust_remote_code=True)
fma_dataset = iter(fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000)))

n_hours = 1  # use only 1 hour of clips for this example notebook, recommend increasing for full-scale training
for i in tqdm(range(n_hours*3600//30)):  # this works because the FMA dataset is all 30 second clips
    row = next(fma_dataset)
    name = row['audio']['path'].split('/')[-1].replace(".mp3", ".wav")
    scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))
    i += 1
    if i == n_hours*3600//30:
        break
# Out:
# --2026-09-15 13:21:28--  https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/bal_train09.tar
# Resolving huggingface.co (huggingface.co)... 3.165.160.61, 3.165.160.12, 3.165.160.59, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.61|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-09-15 13:21:28 ERROR 404: Not Found.
#
# tar: This does not look like a tar archive
# tar: Exiting with failure status due to previous errors
# 0it [00:00, ?it/s]
# Downloading data:   0%|          | 0.00/358M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/7.68G [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
#  99%|█████████▉| 119/120 [00:12<00:00,  9.55it/s]

# %%
# Download pre-computed openWakeWord features for training and validation

# training set (~2,000 hours from the ACAV100M Dataset)
# See https://huggingface.co/datasets/davidscripka/openwakeword_features for more information
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy

# validation set for false positive rate estimation (~11 hours)
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/validation_set_features.npy
# Out:
# --2026-09-15 13:43:27--  https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy
# Resolving huggingface.co (huggingface.co)... 99.86.101.56, 99.86.101.36, 99.86.101.64, ...
# Connecting to huggingface.co (huggingface.co)|99.86.101.56|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/64f3a0b6918ffcc15af6923c/7e1cade4c3fda6a5081158383c8d43c4a3e1e42555150b596b373efddf9b5194?user_id=public&X-Xet-Cas-Uid=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27openwakeword_features_ACAV100M_2000_hrs_16bit.npy%3B+filename%3D%22openwakeword_features_ACAV100M_2000_hrs_16bit.npy%22%3B&Expires=1789483408&Policy=&Signature=MEUCIEY6YErOWeQIoRdLFX0OmcfrNlKj46YimymtQCkEFz35AiEA8w%7EdG5OTnktJGh6aVVXGMRTLmh8BqC6FI53IT%7EIRHb4_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F [following]
# --2026-09-15 13:43:28--  https://us.gcp.cdn.hf.co/xet-bridge-us/64f3a0b6918ffcc15af6923c/7e1cade4c3fda6a5081158383c8d43c4a3e1e42555150b596b373efddf9b5194?user_id=public&X-Xet-Cas-Uid=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27openwakeword_features_ACAV100M_2000_hrs_16bit.npy%3B+filename%3D%22openwakeword_features_ACAV100M_2000_hrs_16bit.npy%22%3B&Expires=1789483408&Policy=&Signature=MEUCIEY6YErOWeQIoRdLFX0OmcfrNlKj46YimymtQCkEFz35AiEA8w%7EdG5OTnktJGh6aVVXGMRTLmh8BqC6FI53IT%7EIRHb4_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 34.36.28.89
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|34.36.28.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17280000128 (16G) [application/octet-stream]
# Saving to: ‘openwakeword_features_ACAV100M_2000_hrs_16bit.npy’
#
# openwakeword_featur 100%[===================>]  16.09G  42.4MB/s    in 4m 30s
#
# 2026-09-15 13:47:58 (61.0 MB/s) - ‘openwakeword_features_ACAV100M_2000_hrs_16bit.npy’ saved [17280000128/17280000128]
#
# --2026-09-15 13:47:58--  https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/validation_set_features.npy
# Resolving huggingface.co (huggingface.co)... 99.86.101.56, 99.86.101.39, 99.86.101.36, ...
# Connecting to huggingface.co (huggingface.co)|99.86.101.56|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/64f3a0b6918ffcc15af6923c/d06b67aa405c24aab66854c32fe850f58387e668e24d58f9c1885d81d86c94cd?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27validation_set_features.npy%3B+filename%3D%22validation_set_features.npy%22%3B&user_id=public&X-Xet-Cas-Uid=public&Expires=1789483678&Policy=&Signature=MEUCIAyN2-t75Bt9I6iR7gvbH-zwp-qtvdQuRHa%7Ez1IfIuy2AiEA6VQcp53pIyvUtxXZby8tVarlj6gn0tdFNJ6tbncA1Do_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F [following]
# --2026-09-15 13:47:58--  https://us.gcp.cdn.hf.co/xet-bridge-us/64f3a0b6918ffcc15af6923c/d06b67aa405c24aab66854c32fe850f58387e668e24d58f9c1885d81d86c94cd?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27validation_set_features.npy%3B+filename%3D%22validation_set_features.npy%22%3B&user_id=public&X-Xet-Cas-Uid=public&Expires=1789483678&Policy=&Signature=MEUCIAyN2-t75Bt9I6iR7gvbH-zwp-qtvdQuRHa%7Ez1IfIuy2AiEA6VQcp53pIyvUtxXZby8tVarlj6gn0tdFNJ6tbncA1Do_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 34.36.28.89
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|34.36.28.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 184836608 (176M) [application/octet-stream]
# Saving to: ‘validation_set_features.npy’
#
# validation_set_feat 100%[===================>] 176.27M  83.2MB/s    in 2.1s
#
# 2026-09-15 13:48:00 (83.2 MB/s) - ‘validation_set_features.npy’ saved [184836608/184836608]

# %% [markdown]
# # Define Training Configuration

# %% [markdown]
# For automated model training openWakeWord uses a specially designed training script and a [YAML](https://yaml.org/) configuration file that defines all of the information required for training a new wake word/phrase detection model.
#
# It is strongly recommended that you review [the example config file](../examples/custom_model.yml), as each value is fully documented there. For the purposes of this notebook, we'll read in the YAML file to modify certain configuration parameters before saving a new YAML file for training our example model. Specifically:
#
# - We'll train a detection model for the phrase "hey sebastian"
# - We'll only generate 5,000 positive and negative examples (to save on time for this example)
# - We'll only generate 1,000 validation positive and negative examples for early stopping (again to save time)
# - The model will only be trained for 10,000 steps (larger datasets will benefit from longer training)
# - We'll reduce the target metrics to account for the small dataset size and limited training.
#
# On the topic of target metrics, there are *not* specific guidelines about what these metrics should be in practice, and you will need to conduct testing in your target deployment environment to establish good thresholds. However, from very limited testing the default values in the config file (accuracy >= 0.7, recall >= 0.5, false-positive rate <= 0.2 per hour) seem to produce models with reasonable performance.

# %%
# Load default YAML config file for training
config = yaml.load(open("openwakeword/examples/custom_model.yml", 'r').read(), yaml.Loader)
config
# Out:
# {'model_name': 'my_model',
#  'target_phrase': ['hey jarvis'],
#  'custom_negative_phrases': [],
#  'n_samples': 10000,
#  'n_samples_val': 2000,
#  'tts_batch_size': 50,
#  'augmentation_batch_size': 16,
#  'piper_sample_generator_path': './piper-sample-generator',
#  'output_dir': './my_custom_model',
#  'rir_paths': ['./mit_rirs'],
#  'background_paths': ['./background_clips'],
#  'background_paths_duplication_rate': [1],
#  'false_positive_validation_data_path': './validation_set_features.npy',
#  'augmentation_rounds': 1,
#  'feature_data_files': {'ACAV100M_sample': './openwakeword_features_ACAV100M_2000_hrs_16bit.npy'},
#  'batch_n_per_class': {'ACAV100M_sample': 1024,
#   'adversarial_negative': 50,
#   'positive': 50},
#  'model_type': 'dnn',
#  'layer_size': 32,
#  'steps': 50000,
#  'max_negative_weight': 1500,
#  'target_false_positives_per_hour': 0.2}

# %%
# Modify values in the config and save a new version

config["target_phrase"] = ["hey sebastian"]
config["model_name"] = config["target_phrase"][0].replace(" ", "_")
config["n_samples"] = 1000
config["n_samples_val"] = 1000
config["steps"] = 10000
config["target_accuracy"] = 0.6
config["target_recall"] = 0.25

config["background_paths"] = ['./audioset_16k', './fma']  # multiple background datasets are supported
config["false_positive_validation_data_path"] = "validation_set_features.npy"
config["feature_data_files"] = {"ACAV100M_sample": "openwakeword_features_ACAV100M_2000_hrs_16bit.npy"}

with open('my_model.yaml', 'w') as file:
    documents = yaml.dump(config, file)

# %% [markdown]
# # Train the Model

# %% [markdown]
# With the data downloaded and training configuration set, we can now start training the model. We'll do this in parts to better illustrate the sequence, but you can also execute every step at once for a fully automated process.

# %%
# !rm -rf piper-sample-generator
# !git clone https://github.com/dscripka/piper-sample-generator
# !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'
# !pip install piper-phonemize
# !pip install webrtcvad
# Out:
# Cloning into 'piper-sample-generator'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 75 (delta 21), reused 18 (delta 18), pack-reused 40 (from 1)
# Receiving objects: 100% (75/75), 1.01 MiB | 16.98 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
# --2026-09-15 13:59:35--  https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/642029941/73f4af3c-7cf8-4547-a7b9-3bd29e7f3c33?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T14%3A52%3A41Z&rscd=attachment%3B+filename%3Den_US-libritts_r-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T13%3A52%3A24Z&ske=2026-09-15T14%3A52%3A41Z&sks=b&skv=2018-11-09&sig=vAidB8SizXywLRhCKu70xdzzV8oZ0%2FQUskmJTbF3%2BE0%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ4NDI4NywibmJmIjoxNzg5NDgwNjg3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.Ek6wGGysJoUPMXDFt5Z6Q5O8zPsfE2kHwlLI78yeUz0&response-content-disposition=attachment%3B%20filename%3Den_US-libritts_r-medium.pt&response-content-type=application%2Foctet-stream [following]
# --2026-09-15 13:59:35--  https://release-assets.githubusercontent.com/github-production-release-asset/642029941/73f4af3c-7cf8-4547-a7b9-3bd29e7f3c33?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T14%3A52%3A41Z&rscd=attachment%3B+filename%3Den_US-libritts_r-medium.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T13%3A52%3A24Z&ske=2026-09-15T14%3A52%3A41Z&sks=b&skv=2018-11-09&sig=vAidB8SizXywLRhCKu70xdzzV8oZ0%2FQUskmJTbF3%2BE0%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ4NDI4NywibmJmIjoxNzg5NDgwNjg3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.Ek6wGGysJoUPMXDFt5Z6Q5O8zPsfE2kHwlLI78yeUz0&response-content-disposition=attachment%3B%20filename%3Den_US-libritts_r-medium.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 204089915 (195M) [application/octet-stream]
# Saving to: ‘piper-sample-generator/models/en_US-libritts_r-medium.pt’
#
# piper-sample-genera 100%[===================>] 194.63M   232MB/s    in 0.8s
#
# 2026-09-15 13:59:36 (232 MB/s) - ‘piper-sample-generator/models/en_US-libritts_r-medium.pt’ saved [204089915/204089915]
#
# ERROR: Could not find a version that satisfies the requirement piper-phonemize (from versions: none)
# ERROR: No matching distribution found for piper-phonemize
# Requirement already satisfied: webrtcvad in /usr/local/lib/python3.13/dist-packages (2.0.10)

# %%
# !apt-get install -y espeak-ng
# !{sys.executable} -m pip install -r piper-sample-generator/requirements.txt
# !wget -O piper-sample-generator/models/en-us-libritts-high.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v1.0.0/en-us-libritts-high.pt'
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# espeak-ng is already the newest version (1.51+dfsg-12build1).
# 0 upgraded, 0 newly installed, 0 to remove and 52 not upgraded.
# Requirement already satisfied: audiomentations in /usr/local/lib/python3.13/dist-packages (from -r piper-sample-generator/requirements.txt (line 1)) (0.33.0)
# Requirement already satisfied: espeak-phonemizer in /usr/local/lib/python3.13/dist-packages (from -r piper-sample-generator/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from -r piper-sample-generator/requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (from -r piper-sample-generator/requirements.txt (line 4)) (2.11.0+cu128)
# Requirement already satisfied: webrtcvad in /usr/local/lib/python3.13/dist-packages (from -r piper-sample-generator/requirements.txt (line 5)) (2.0.10)
# Requirement already satisfied: librosa!=0.10.0,<0.11.0,>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (0.10.2.post1)
# Requirement already satisfied: scipy<2,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (1.16.3)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /usr/local/lib/python3.13/dist-packages (from audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (0.5.0.post1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (2023.10.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch->-r piper-sample-generator/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->-r piper-sample-generator/requirements.txt (line 4)) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch->-r piper-sample-generator/requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (0.61.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.13/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch->-r piper-sample-generator/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch->-r piper-sample-generator/requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: standard-aifc in /usr/local/lib/python3.13/dist-packages (from audioread>=2.1.9->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: standard-sunau in /usr/local/lib/python3.13/dist-packages (from audioread>=2.1.9->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=0.14->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from lazy-loader>=0.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (26.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (4.11.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.13/dist-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=0.20.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.13/dist-packages (from soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (2026.7.22)
# Requirement already satisfied: standard-chunk in /usr/local/lib/python3.13/dist-packages (from standard-aifc->audioread>=2.1.9->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: audioop-lts in /usr/local/lib/python3.13/dist-packages (from standard-aifc->audioread>=2.1.9->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->-r piper-sample-generator/requirements.txt (line 1)) (0.2.2)
# --2026-09-15 14:03:07--  https://github.com/rhasspy/piper-sample-generator/releases/download/v1.0.0/en-us-libritts-high.pt
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/642029941/40dc6d54-317d-4987-a114-8f2a02c04126?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T14%3A59%3A39Z&rscd=attachment%3B+filename%3Den-us-libritts-high.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T13%3A58%3A58Z&ske=2026-09-15T14%3A59%3A39Z&sks=b&skv=2018-11-09&sig=zrZFw%2F96CdgR8UIbrtbpkhsTc0PTpFCxHN9plsyAaqQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ4NDU4NywibmJmIjoxNzg5NDgwOTg3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.5jH-3clDx_KeTi1dmW9L0yID3Zm6EEO5R5pWUCictxY&response-content-disposition=attachment%3B%20filename%3Den-us-libritts-high.pt&response-content-type=application%2Foctet-stream [following]
# --2026-09-15 14:03:07--  https://release-assets.githubusercontent.com/github-production-release-asset/642029941/40dc6d54-317d-4987-a114-8f2a02c04126?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-09-15T14%3A59%3A39Z&rscd=attachment%3B+filename%3Den-us-libritts-high.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-09-15T13%3A58%3A58Z&ske=2026-09-15T14%3A59%3A39Z&sks=b&skv=2018-11-09&sig=zrZFw%2F96CdgR8UIbrtbpkhsTc0PTpFCxHN9plsyAaqQ%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc4OTQ4NDU4NywibmJmIjoxNzg5NDgwOTg3LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.5jH-3clDx_KeTi1dmW9L0yID3Zm6EEO5R5pWUCictxY&response-content-disposition=attachment%3B%20filename%3Den-us-libritts-high.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255226835 (243M) [application/octet-stream]
# Saving to: ‘piper-sample-generator/models/en-us-libritts-high.pt’
#
# piper-sample-genera 100%[===================>] 243.40M   186MB/s    in 1.3s
#
# 2026-09-15 14:03:08 (186 MB/s) - ‘piper-sample-generator/models/en-us-libritts-high.pt’ saved [255226835/255226835]

# %%
# !sed -i 's/model = torch.load(model_path)/model = torch.load(model_path, weights_only=False)/' piper-sample-generator/generate_samples.py

# %%
# Step 1: Generate synthetic clips
# For the number of clips we are using, this should take ~10 minutes on a free Google Colab instance with a T4 GPU
# If generation fails, you can simply run this command again as it will continue generating until the
# number of files meets the targets specified in the config file

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --generate_clips
# Out:
# /usr/local/lib/python3.13/dist-packages/pronouncing/__init__.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream
# INFO:root:##################################################
# Generating positive clips for training
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en-us-libritts-high.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# /content/piper-sample-generator/generate_samples.py:113: UserWarning: "kaiser_window" resampling method name is being deprecated and replaced by "sinc_interp_kaiser" in the next release. The default behavior remains unchanged.
#   resampler = torchaudio.transforms.Resample(
# DEBUG:generate_samples:Batch 1/20 complete
# DEBUG:generate_samples:Batch 2/20 complete
# DEBUG:generate_samples:Batch 3/20 complete
# DEBUG:generate_samples:Batch 4/20 complete
# DEBUG:generate_samples:Batch 5/20 complete
# DEBUG:generate_samples:Batch 6/20 complete
# DEBUG:generate_samples:Batch 7/20 complete
# DEBUG:generate_samples:Batch 8/20 complete
# DEBUG:generate_samples:Batch 9/20 complete
# DEBUG:generate_samples:Batch 10/20 complete
# DEBUG:generate_samples:Batch 11/20 complete
# DEBUG:generate_samples:Batch 12/20 complete
# DEBUG:generate_samples:Batch 13/20 complete
# DEBUG:generate_samples:Batch 14/20 complete
# DEBUG:generate_samples:Batch 15/20 complete
# DEBUG:generate_samples:Batch 16/20 complete
# DEBUG:generate_samples:Batch 17/20 complete
# DEBUG:generate_samples:Batch 18/20 complete
# DEBUG:generate_samples:Batch 19/20 complete
# DEBUG:generate_samples:Batch 20/20 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating positive clips for testing
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en-us-libritts-high.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/20 complete
# DEBUG:generate_samples:Batch 2/20 complete
# DEBUG:generate_samples:Batch 3/20 complete
# DEBUG:generate_samples:Batch 4/20 complete
# DEBUG:generate_samples:Batch 5/20 complete
# DEBUG:generate_samples:Batch 6/20 complete
# DEBUG:generate_samples:Batch 7/20 complete
# DEBUG:generate_samples:Batch 8/20 complete
# DEBUG:generate_samples:Batch 9/20 complete
# DEBUG:generate_samples:Batch 10/20 complete
# DEBUG:generate_samples:Batch 11/20 complete
# DEBUG:generate_samples:Batch 12/20 complete
# DEBUG:generate_samples:Batch 13/20 complete
# DEBUG:generate_samples:Batch 14/20 complete
# DEBUG:generate_samples:Batch 15/20 complete
# DEBUG:generate_samples:Batch 16/20 complete
# DEBUG:generate_samples:Batch 17/20 complete
# DEBUG:generate_samples:Batch 18/20 complete
# DEBUG:generate_samples:Batch 19/20 complete
# DEBUG:generate_samples:Batch 20/20 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating negative clips for training
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en-us-libritts-high.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/142 complete
# DEBUG:generate_samples:Batch 2/142 complete
# DEBUG:generate_samples:Batch 3/142 complete
# DEBUG:generate_samples:Batch 4/142 complete
# DEBUG:generate_samples:Batch 5/142 complete
# DEBUG:generate_samples:Batch 6/142 complete
# DEBUG:generate_samples:Batch 7/142 complete
# DEBUG:generate_samples:Batch 8/142 complete
# DEBUG:generate_samples:Batch 9/142 complete
# DEBUG:generate_samples:Batch 10/142 complete
# DEBUG:generate_samples:Batch 11/142 complete
# DEBUG:generate_samples:Batch 12/142 complete
# DEBUG:generate_samples:Batch 13/142 complete
# DEBUG:generate_samples:Batch 14/142 complete
# DEBUG:generate_samples:Batch 15/142 complete
# DEBUG:generate_samples:Batch 16/142 complete
# DEBUG:generate_samples:Batch 17/142 complete
# DEBUG:generate_samples:Batch 18/142 complete
# DEBUG:generate_samples:Batch 19/142 complete
# DEBUG:generate_samples:Batch 20/142 complete
# DEBUG:generate_samples:Batch 21/142 complete
# DEBUG:generate_samples:Batch 22/142 complete
# DEBUG:generate_samples:Batch 23/142 complete
# DEBUG:generate_samples:Batch 24/142 complete
# DEBUG:generate_samples:Batch 25/142 complete
# DEBUG:generate_samples:Batch 26/142 complete
# DEBUG:generate_samples:Batch 27/142 complete
# DEBUG:generate_samples:Batch 28/142 complete
# DEBUG:generate_samples:Batch 29/142 complete
# DEBUG:generate_samples:Batch 30/142 complete
# DEBUG:generate_samples:Batch 31/142 complete
# DEBUG:generate_samples:Batch 32/142 complete
# DEBUG:generate_samples:Batch 33/142 complete
# DEBUG:generate_samples:Batch 34/142 complete
# DEBUG:generate_samples:Batch 35/142 complete
# DEBUG:generate_samples:Batch 36/142 complete
# DEBUG:generate_samples:Batch 37/142 complete
# DEBUG:generate_samples:Batch 38/142 complete
# DEBUG:generate_samples:Batch 39/142 complete
# DEBUG:generate_samples:Batch 40/142 complete
# DEBUG:generate_samples:Batch 41/142 complete
# DEBUG:generate_samples:Batch 42/142 complete
# DEBUG:generate_samples:Batch 43/142 complete
# DEBUG:generate_samples:Batch 44/142 complete
# DEBUG:generate_samples:Batch 45/142 complete
# DEBUG:generate_samples:Batch 46/142 complete
# DEBUG:generate_samples:Batch 47/142 complete
# DEBUG:generate_samples:Batch 48/142 complete
# DEBUG:generate_samples:Batch 49/142 complete
# DEBUG:generate_samples:Batch 50/142 complete
# DEBUG:generate_samples:Batch 51/142 complete
# DEBUG:generate_samples:Batch 52/142 complete
# DEBUG:generate_samples:Batch 53/142 complete
# DEBUG:generate_samples:Batch 54/142 complete
# DEBUG:generate_samples:Batch 55/142 complete
# DEBUG:generate_samples:Batch 56/142 complete
# DEBUG:generate_samples:Batch 57/142 complete
# DEBUG:generate_samples:Batch 58/142 complete
# DEBUG:generate_samples:Batch 59/142 complete
# DEBUG:generate_samples:Batch 60/142 complete
# DEBUG:generate_samples:Batch 61/142 complete
# DEBUG:generate_samples:Batch 62/142 complete
# DEBUG:generate_samples:Batch 63/142 complete
# DEBUG:generate_samples:Batch 64/142 complete
# DEBUG:generate_samples:Batch 65/142 complete
# DEBUG:generate_samples:Batch 66/142 complete
# DEBUG:generate_samples:Batch 67/142 complete
# DEBUG:generate_samples:Batch 68/142 complete
# DEBUG:generate_samples:Batch 69/142 complete
# DEBUG:generate_samples:Batch 70/142 complete
# DEBUG:generate_samples:Batch 71/142 complete
# DEBUG:generate_samples:Batch 72/142 complete
# DEBUG:generate_samples:Batch 73/142 complete
# DEBUG:generate_samples:Batch 74/142 complete
# DEBUG:generate_samples:Batch 75/142 complete
# DEBUG:generate_samples:Batch 76/142 complete
# DEBUG:generate_samples:Batch 77/142 complete
# DEBUG:generate_samples:Batch 78/142 complete
# DEBUG:generate_samples:Batch 79/142 complete
# DEBUG:generate_samples:Batch 80/142 complete
# DEBUG:generate_samples:Batch 81/142 complete
# DEBUG:generate_samples:Batch 82/142 complete
# DEBUG:generate_samples:Batch 83/142 complete
# DEBUG:generate_samples:Batch 84/142 complete
# DEBUG:generate_samples:Batch 85/142 complete
# DEBUG:generate_samples:Batch 86/142 complete
# DEBUG:generate_samples:Batch 87/142 complete
# DEBUG:generate_samples:Batch 88/142 complete
# DEBUG:generate_samples:Batch 89/142 complete
# DEBUG:generate_samples:Batch 90/142 complete
# DEBUG:generate_samples:Batch 91/142 complete
# DEBUG:generate_samples:Batch 92/142 complete
# DEBUG:generate_samples:Batch 93/142 complete
# DEBUG:generate_samples:Batch 94/142 complete
# DEBUG:generate_samples:Batch 95/142 complete
# DEBUG:generate_samples:Batch 96/142 complete
# DEBUG:generate_samples:Batch 97/142 complete
# DEBUG:generate_samples:Batch 98/142 complete
# DEBUG:generate_samples:Batch 99/142 complete
# DEBUG:generate_samples:Batch 100/142 complete
# DEBUG:generate_samples:Batch 101/142 complete
# DEBUG:generate_samples:Batch 102/142 complete
# DEBUG:generate_samples:Batch 103/142 complete
# DEBUG:generate_samples:Batch 104/142 complete
# DEBUG:generate_samples:Batch 105/142 complete
# DEBUG:generate_samples:Batch 106/142 complete
# DEBUG:generate_samples:Batch 107/142 complete
# DEBUG:generate_samples:Batch 108/142 complete
# DEBUG:generate_samples:Batch 109/142 complete
# DEBUG:generate_samples:Batch 110/142 complete
# DEBUG:generate_samples:Batch 111/142 complete
# DEBUG:generate_samples:Batch 112/142 complete
# DEBUG:generate_samples:Batch 113/142 complete
# DEBUG:generate_samples:Batch 114/142 complete
# DEBUG:generate_samples:Batch 115/142 complete
# DEBUG:generate_samples:Batch 116/142 complete
# DEBUG:generate_samples:Batch 117/142 complete
# DEBUG:generate_samples:Batch 118/142 complete
# DEBUG:generate_samples:Batch 119/142 complete
# DEBUG:generate_samples:Batch 120/142 complete
# DEBUG:generate_samples:Batch 121/142 complete
# DEBUG:generate_samples:Batch 122/142 complete
# DEBUG:generate_samples:Batch 123/142 complete
# DEBUG:generate_samples:Batch 124/142 complete
# DEBUG:generate_samples:Batch 125/142 complete
# DEBUG:generate_samples:Batch 126/142 complete
# DEBUG:generate_samples:Batch 127/142 complete
# DEBUG:generate_samples:Batch 128/142 complete
# DEBUG:generate_samples:Batch 129/142 complete
# DEBUG:generate_samples:Batch 130/142 complete
# DEBUG:generate_samples:Batch 131/142 complete
# DEBUG:generate_samples:Batch 132/142 complete
# DEBUG:generate_samples:Batch 133/142 complete
# DEBUG:generate_samples:Batch 134/142 complete
# DEBUG:generate_samples:Batch 135/142 complete
# DEBUG:generate_samples:Batch 136/142 complete
# DEBUG:generate_samples:Batch 137/142 complete
# DEBUG:generate_samples:Batch 138/142 complete
# DEBUG:generate_samples:Batch 139/142 complete
# DEBUG:generate_samples:Batch 140/142 complete
# DEBUG:generate_samples:Batch 141/142 complete
# DEBUG:generate_samples:Batch 142/142 complete
# DEBUG:generate_samples:Batch 143/142 complete
# INFO:generate_samples:Done
# INFO:root:##################################################
# Generating negative clips for testing
# ##################################################
# DEBUG:generate_samples:Loading /content/piper-sample-generator/models/en-us-libritts-high.pt
# INFO:generate_samples:Successfully loaded the model
# DEBUG:generate_samples:CUDA available, using GPU
# DEBUG:generate_samples:Batch 1/142 complete
# DEBUG:generate_samples:Batch 2/142 complete
# DEBUG:generate_samples:Batch 3/142 complete
# DEBUG:generate_samples:Batch 4/142 complete
# DEBUG:generate_samples:Batch 5/142 complete
# DEBUG:generate_samples:Batch 6/142 complete
# DEBUG:generate_samples:Batch 7/142 complete
# DEBUG:generate_samples:Batch 8/142 complete
# DEBUG:generate_samples:Batch 9/142 complete
# DEBUG:generate_samples:Batch 10/142 complete
# DEBUG:generate_samples:Batch 11/142 complete
# DEBUG:generate_samples:Batch 12/142 complete
# DEBUG:generate_samples:Batch 13/142 complete
# DEBUG:generate_samples:Batch 14/142 complete
# DEBUG:generate_samples:Batch 15/142 complete
# DEBUG:generate_samples:Batch 16/142 complete
# DEBUG:generate_samples:Batch 17/142 complete
# DEBUG:generate_samples:Batch 18/142 complete
# DEBUG:generate_samples:Batch 19/142 complete
# DEBUG:generate_samples:Batch 20/142 complete
# DEBUG:generate_samples:Batch 21/142 complete
# DEBUG:generate_samples:Batch 22/142 complete
# DEBUG:generate_samples:Batch 23/142 complete
# DEBUG:generate_samples:Batch 24/142 complete
# DEBUG:generate_samples:Batch 25/142 complete
# DEBUG:generate_samples:Batch 26/142 complete
# DEBUG:generate_samples:Batch 27/142 complete
# DEBUG:generate_samples:Batch 28/142 complete
# DEBUG:generate_samples:Batch 29/142 complete
# DEBUG:generate_samples:Batch 30/142 complete
# DEBUG:generate_samples:Batch 31/142 complete
# DEBUG:generate_samples:Batch 32/142 complete
# DEBUG:generate_samples:Batch 33/142 complete
# DEBUG:generate_samples:Batch 34/142 complete
# DEBUG:generate_samples:Batch 35/142 complete
# DEBUG:generate_samples:Batch 36/142 complete
# DEBUG:generate_samples:Batch 37/142 complete
# DEBUG:generate_samples:Batch 38/142 complete
# DEBUG:generate_samples:Batch 39/142 complete
# DEBUG:generate_samples:Batch 40/142 complete
# DEBUG:generate_samples:Batch 41/142 complete
# DEBUG:generate_samples:Batch 42/142 complete
# DEBUG:generate_samples:Batch 43/142 complete
# DEBUG:generate_samples:Batch 44/142 complete
# DEBUG:generate_samples:Batch 45/142 complete
# DEBUG:generate_samples:Batch 46/142 complete
# DEBUG:generate_samples:Batch 47/142 complete
# DEBUG:generate_samples:Batch 48/142 complete
# DEBUG:generate_samples:Batch 49/142 complete
# DEBUG:generate_samples:Batch 50/142 complete
# DEBUG:generate_samples:Batch 51/142 complete
# DEBUG:generate_samples:Batch 52/142 complete
# DEBUG:generate_samples:Batch 53/142 complete
# DEBUG:generate_samples:Batch 54/142 complete
# DEBUG:generate_samples:Batch 55/142 complete
# DEBUG:generate_samples:Batch 56/142 complete
# DEBUG:generate_samples:Batch 57/142 complete
# DEBUG:generate_samples:Batch 58/142 complete
# DEBUG:generate_samples:Batch 59/142 complete
# DEBUG:generate_samples:Batch 60/142 complete
# DEBUG:generate_samples:Batch 61/142 complete
# DEBUG:generate_samples:Batch 62/142 complete
# DEBUG:generate_samples:Batch 63/142 complete
# DEBUG:generate_samples:Batch 64/142 complete
# DEBUG:generate_samples:Batch 65/142 complete
# DEBUG:generate_samples:Batch 66/142 complete
# DEBUG:generate_samples:Batch 67/142 complete
# DEBUG:generate_samples:Batch 68/142 complete
# DEBUG:generate_samples:Batch 69/142 complete
# DEBUG:generate_samples:Batch 70/142 complete
# DEBUG:generate_samples:Batch 71/142 complete
# DEBUG:generate_samples:Batch 72/142 complete
# DEBUG:generate_samples:Batch 73/142 complete
# DEBUG:generate_samples:Batch 74/142 complete
# DEBUG:generate_samples:Batch 75/142 complete
# DEBUG:generate_samples:Batch 76/142 complete
# DEBUG:generate_samples:Batch 77/142 complete
# DEBUG:generate_samples:Batch 78/142 complete
# DEBUG:generate_samples:Batch 79/142 complete
# DEBUG:generate_samples:Batch 80/142 complete
# DEBUG:generate_samples:Batch 81/142 complete
# DEBUG:generate_samples:Batch 82/142 complete
# DEBUG:generate_samples:Batch 83/142 complete
# DEBUG:generate_samples:Batch 84/142 complete
# DEBUG:generate_samples:Batch 85/142 complete
# DEBUG:generate_samples:Batch 86/142 complete
# DEBUG:generate_samples:Batch 87/142 complete
# DEBUG:generate_samples:Batch 88/142 complete
# DEBUG:generate_samples:Batch 89/142 complete
# DEBUG:generate_samples:Batch 90/142 complete
# DEBUG:generate_samples:Batch 91/142 complete
# DEBUG:generate_samples:Batch 92/142 complete
# DEBUG:generate_samples:Batch 93/142 complete
# DEBUG:generate_samples:Batch 94/142 complete
# DEBUG:generate_samples:Batch 95/142 complete
# DEBUG:generate_samples:Batch 96/142 complete
# DEBUG:generate_samples:Batch 97/142 complete
# DEBUG:generate_samples:Batch 98/142 complete
# DEBUG:generate_samples:Batch 99/142 complete
# DEBUG:generate_samples:Batch 100/142 complete
# DEBUG:generate_samples:Batch 101/142 complete
# DEBUG:generate_samples:Batch 102/142 complete
# DEBUG:generate_samples:Batch 103/142 complete
# DEBUG:generate_samples:Batch 104/142 complete
# DEBUG:generate_samples:Batch 105/142 complete
# DEBUG:generate_samples:Batch 106/142 complete
# DEBUG:generate_samples:Batch 107/142 complete
# DEBUG:generate_samples:Batch 108/142 complete
# DEBUG:generate_samples:Batch 109/142 complete
# DEBUG:generate_samples:Batch 110/142 complete
# DEBUG:generate_samples:Batch 111/142 complete
# DEBUG:generate_samples:Batch 112/142 complete
# DEBUG:generate_samples:Batch 113/142 complete
# DEBUG:generate_samples:Batch 114/142 complete
# DEBUG:generate_samples:Batch 115/142 complete
# DEBUG:generate_samples:Batch 116/142 complete
# DEBUG:generate_samples:Batch 117/142 complete
# DEBUG:generate_samples:Batch 118/142 complete
# DEBUG:generate_samples:Batch 119/142 complete
# DEBUG:generate_samples:Batch 120/142 complete
# DEBUG:generate_samples:Batch 121/142 complete
# DEBUG:generate_samples:Batch 122/142 complete
# DEBUG:generate_samples:Batch 123/142 complete
# DEBUG:generate_samples:Batch 124/142 complete
# DEBUG:generate_samples:Batch 125/142 complete
# DEBUG:generate_samples:Batch 126/142 complete
# DEBUG:generate_samples:Batch 127/142 complete
# DEBUG:generate_samples:Batch 128/142 complete
# DEBUG:generate_samples:Batch 129/142 complete
# DEBUG:generate_samples:Batch 130/142 complete
# DEBUG:generate_samples:Batch 131/142 complete
# DEBUG:generate_samples:Batch 132/142 complete
# DEBUG:generate_samples:Batch 133/142 complete
# DEBUG:generate_samples:Batch 134/142 complete
# DEBUG:generate_samples:Batch 135/142 complete
# DEBUG:generate_samples:Batch 136/142 complete
# DEBUG:generate_samples:Batch 137/142 complete
# DEBUG:generate_samples:Batch 138/142 complete
# DEBUG:generate_samples:Batch 139/142 complete
# DEBUG:generate_samples:Batch 140/142 complete
# DEBUG:generate_samples:Batch 141/142 complete
# DEBUG:generate_samples:Batch 142/142 complete
# DEBUG:generate_samples:Batch 143/142 complete
# INFO:generate_samples:Done

# %%
# !{sys.executable} -m pip install soundfile
# !sed -i "s/import torchaudio/import torchaudio\nimport soundfile/" /usr/local/lib/python3.13/dist-packages/torch_audiomentations/utils/io.py
# !sed -i 's/info = torchaudio.info(str(file_path))/_sf = soundfile.info(str(file_path)); info = type("Info", (), {"num_frames": _sf.frames, "sample_rate": _sf.samplerate})()/' /usr/local/lib/python3.13/dist-packages/torch_audiomentations/utils/io.py
# Out:
# Requirement already satisfied: soundfile in /usr/local/lib/python3.13/dist-packages (0.14.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.13/dist-packages (from soundfile) (2.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from soundfile) (2.1.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.13/dist-packages (from soundfile) (4.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0->soundfile) (3.0)

# %%
# !find . -name "*features*.npy" -exec rm -v {} \;
# Out:
# removed './my_custom_model/hey_sebastian/positive_features_train.npy'
# removed './openwakeword_features_ACAV100M_2000_hrs_16bit.npy'
# removed './validation_set_features.npy'

# %%
# Step 2: Augment the generated clips

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --augment_clips
# Out:
# /usr/local/lib/python3.13/dist-packages/pronouncing/__init__.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream
# INFO:root:##################################################
# Computing openwakeword features for generated samples
# ##################################################
# /usr/local/lib/python3.13/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:197: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = PitchShift(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = BandStopFilter(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = AddColoredNoise(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = AddBackgroundNoise(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/transforms_interface.py:76: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = Gain(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/torch_audiomentations/core/composition.py:42: FutureWarning: Transforms now expect an `output_type` argument that currently defaults to 'tensor', will default to 'dict' in v0.12, and will be removed in v0.13. Make sure to update your code to something like:
#   >>> augment = Compose(..., output_type='dict')
#   >>> augmented_samples = augment(samples).samples
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/audiomentations/core/transforms_interface.py:61: UserWarning: Warning: input samples dtype is np.float64. Converting to np.float32
#   warnings.warn(
# Computing features: 100% 62/62 [00:45<00:00,  1.36it/s]
# Trimming empty rows: 1it [00:00, 45.30it/s]
# Computing features: 100% 62/62 [00:42<00:00,  1.45it/s]
# Trimming empty rows: 1it [00:00, 49.29it/s]
# Computing features: 100% 62/62 [00:42<00:00,  1.44it/s]
# Trimming empty rows: 1it [00:00, 47.78it/s]
# Computing features: 100% 62/62 [00:42<00:00,  1.45it/s]
# Trimming empty rows: 1it [00:00, 40.81it/s]

# %%
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy
# !wget https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/validation_set_features.npy
# Out:
# --2026-09-15 14:18:51--  https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/openwakeword_features_ACAV100M_2000_hrs_16bit.npy
# Resolving huggingface.co (huggingface.co)... 99.86.101.64, 99.86.101.36, 99.86.101.39, ...
# Connecting to huggingface.co (huggingface.co)|99.86.101.64|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/64f3a0b6918ffcc15af6923c/7e1cade4c3fda6a5081158383c8d43c4a3e1e42555150b596b373efddf9b5194?user_id=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27openwakeword_features_ACAV100M_2000_hrs_16bit.npy%3B+filename%3D%22openwakeword_features_ACAV100M_2000_hrs_16bit.npy%22%3B&X-Xet-Cas-Uid=public&Expires=1789485531&Policy=&Signature=MEUCIQCUO%7E61kXT8P3W2w%7Er8-DBBHf3G-36qywQ8E71m4Bhz8QIgaHl3uxlP8MHpYj-lHQC4vniHkmxZOekdyND%7EVW1JluM_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F [following]
# --2026-09-15 14:18:51--  https://us.gcp.cdn.hf.co/xet-bridge-us/64f3a0b6918ffcc15af6923c/7e1cade4c3fda6a5081158383c8d43c4a3e1e42555150b596b373efddf9b5194?user_id=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27openwakeword_features_ACAV100M_2000_hrs_16bit.npy%3B+filename%3D%22openwakeword_features_ACAV100M_2000_hrs_16bit.npy%22%3B&X-Xet-Cas-Uid=public&Expires=1789485531&Policy=&Signature=MEUCIQCUO%7E61kXT8P3W2w%7Er8-DBBHf3G-36qywQ8E71m4Bhz8QIgaHl3uxlP8MHpYj-lHQC4vniHkmxZOekdyND%7EVW1JluM_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 34.36.28.89
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|34.36.28.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17280000128 (16G) [application/octet-stream]
# Saving to: ‘openwakeword_features_ACAV100M_2000_hrs_16bit.npy’
#
# openwakeword_featur 100%[===================>]  16.09G  45.3MB/s    in 3m 48s
#
# 2026-09-15 14:22:39 (72.2 MB/s) - ‘openwakeword_features_ACAV100M_2000_hrs_16bit.npy’ saved [17280000128/17280000128]
#
# --2026-09-15 14:22:39--  https://huggingface.co/datasets/davidscripka/openwakeword_features/resolve/main/validation_set_features.npy
# Resolving huggingface.co (huggingface.co)... 99.86.101.39, 99.86.101.64, 99.86.101.56, ...
# Connecting to huggingface.co (huggingface.co)|99.86.101.39|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/64f3a0b6918ffcc15af6923c/d06b67aa405c24aab66854c32fe850f58387e668e24d58f9c1885d81d86c94cd?user_id=public&X-Xet-Cas-Uid=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27validation_set_features.npy%3B+filename%3D%22validation_set_features.npy%22%3B&Expires=1789485759&Policy=&Signature=MEUCIDtXhhzK84N3bOoOPhcpG14ajkYrgQTYQUWK7Z1bZBc6AiEA4tE3S3%7EhvWKTsrfq8fPuizHSAzBJl9HO7odNFbuG7GQ_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F [following]
# --2026-09-15 14:22:40--  https://us.gcp.cdn.hf.co/xet-bridge-us/64f3a0b6918ffcc15af6923c/d06b67aa405c24aab66854c32fe850f58387e668e24d58f9c1885d81d86c94cd?user_id=public&X-Xet-Cas-Uid=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27validation_set_features.npy%3B+filename%3D%22validation_set_features.npy%22%3B&Expires=1789485759&Policy=&Signature=MEUCIDtXhhzK84N3bOoOPhcpG14ajkYrgQTYQUWK7Z1bZBc6AiEA4tE3S3%7EhvWKTsrfq8fPuizHSAzBJl9HO7odNFbuG7GQ_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 34.36.28.89
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|34.36.28.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 184836608 (176M) [application/octet-stream]
# Saving to: ‘validation_set_features.npy’
#
# validation_set_feat 100%[===================>] 176.27M  70.9MB/s    in 2.5s
#
# 2026-09-15 14:22:42 (70.9 MB/s) - ‘validation_set_features.npy’ saved [184836608/184836608]

# %%
# !{sys.executable} -m pip install onnxscript
# Out:
# Collecting onnxscript
#   Downloading onnxscript-0.7.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.13/dist-packages (from onnxscript) (0.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from onnxscript) (2.1.3)
# Collecting onnx_ir<2,>=0.1.16 (from onnxscript)
#   Downloading onnx_ir-1.0.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting onnx>=1.17 (from onnxscript)
#   Using cached onnx-1.22.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from onnxscript) (26.3)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.13/dist-packages (from onnxscript) (4.16.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.13/dist-packages (from onnx>=1.17->onnxscript) (5.29.6)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.13/dist-packages (from onnx_ir<2,>=0.1.16->onnxscript) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.16->onnxscript) (1.3.0)
# Downloading onnxscript-0.7.2-py3-none-any.whl (754 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 754.2/754.2 kB 17.3 MB/s eta 0:00:00
# Downloading onnx-1.22.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 86.8 MB/s eta 0:00:00
# Downloading onnx_ir-1.0.0-py3-none-any.whl (185 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 18.9 MB/s eta 0:00:00
# Installing collected packages: onnx, onnx_ir, onnxscript
# Successfully installed onnx-1.22.0 onnx_ir-1.0.0 onnxscript-0.7.2

# %%
# Step 3: Train model

# !{sys.executable} openwakeword/openwakeword/train.py --training_config my_model.yaml --train_model
# Out:
# /usr/local/lib/python3.13/dist-packages/pronouncing/__init__.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream
# INFO:root:##################################################
# Starting training sequence 1...
# ##################################################
# Training: 100% 9999/10000 [05:43<00:00, 29.13it/s]
# INFO:root:##################################################
# Starting training sequence 2...
# ##################################################
# INFO:root:Increasing weight on negative examples to reduce false positives...
# Training: 100% 999/1000.0 [02:37<00:00,  6.34it/s]
# INFO:root:##################################################
# Starting training sequence 3...
# ##################################################
# INFO:root:Increasing weight on negative examples to reduce false positives...
# Training: 100% 999/1000.0 [02:39<00:00,  6.26it/s]
# INFO:root:Merging checkpoints above the 90th percentile into single model...
# INFO:root:
# ################
# Final Model Accuracy: 0.718999981880188
# Final Model Recall: 0.44600000977516174
# Final Model False Positives per Hour: 0.17699114978313446
# ################
#
# INFO:root:####
# Saving ONNX mode as '/content/my_custom_model/hey_sebastian.onnx'
# /content/openwakeword/openwakeword/train.py:429: UserWarning: Exporting a model while it is in training mode. Please ensure that this is intended, as it may lead to different behavior during inference. Calling model.eval() before export is recommended.
#   torch.onnx.export(model_to_save.to("cpu"), torch.rand(self.input_shape)[None, ],
# W0915 14:47:45.503000 30324 torch/onnx/_internal/exporter/_compat.py:133] Setting ONNX exporter to use operator set version 18 because the requested opset_version 13 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_abs' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_abs_complex' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_add' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_add_complex' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_gelu_opset20' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_group_norm' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_rms_norm' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_scaled_dot_product_attention_23' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'sym_float' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'sym_max' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'sym_min' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'sym_not' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'sym_sum' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'sym_ite' and there is not one found in opset 'pkg.torch.onnx'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:Rank
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'Rank' and there is not one found in opset 'pkg.onnxscript.torch_lib.common'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:IsScalar
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'IsScalar' and there is not one found in opset 'pkg.onnxscript.torch_lib.common'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten__local_scalar_dense' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten__log_softmax' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten__softmax' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_abs' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_abs_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_acos' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_acosh' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_add' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_add_scalar' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'operator_add' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_add_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_addbmm
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:batch1
# DEBUG:onnxscript:Converter:_bind:batch2
# DEBUG:onnxscript:Converter:_bind:beta
# DEBUG:onnxscript:Converter:_bind:alpha
# DEBUG:onnxscript:Converter:_bind:scaled_self
# DEBUG:onnxscript:Converter:_bind:axes
# DEBUG:onnxscript:Converter:_bind:reduced_batches
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_addbmm' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_addcdiv
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:tensor1
# DEBUG:onnxscript:Converter:_bind:tensor2
# DEBUG:onnxscript:Converter:_bind:value
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_addcdiv' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_addcmul
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:tensor1
# DEBUG:onnxscript:Converter:_bind:tensor2
# DEBUG:onnxscript:Converter:_bind:value
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_addcmul' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_addmm' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_addmv
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:mat
# DEBUG:onnxscript:Converter:_bind:vec
# DEBUG:onnxscript:Converter:_bind:beta
# DEBUG:onnxscript:Converter:_bind:alpha
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_addmv' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_addr' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_alias' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_all' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_all_dim' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_all_dims' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_allclose
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:rtol
# DEBUG:onnxscript:Converter:_bind:atol
# DEBUG:onnxscript:Converter:_bind:equal_nan
# DEBUG:onnxscript:Converter:_bind:left_part
# DEBUG:onnxscript:Converter:_bind:right_part
# DEBUG:onnxscript:Converter:_bind:is_close
# DEBUG:onnxscript:Converter:_bind:is_close_int
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_allclose' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_amax
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:dim
# DEBUG:onnxscript:Converter:_bind:keepdim
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_amax' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_amin
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:dim
# DEBUG:onnxscript:Converter:_bind:keepdim
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_amin' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_angle' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_angle_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_any' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_any_dim' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_any_dims' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_arange' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_arange_start' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_arange_start_step' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_argmax' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_argmin' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_as_strided' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_asin' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_asinh' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_atan' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_atan2' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_atanh' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_atleast_1d' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_atleast_1d_sequence
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'ast.FunctionDef'>
# DEBUG:onnxscript:Converter:_translate_function_def_common:reshape_to_1d
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_bind:shape
# DEBUG:onnxscript:Converter:_bind:rank
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:reshape_to_1d
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_atleast_1d_sequence' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_atleast_2d' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_atleast_2d_sequence
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'ast.FunctionDef'>
# DEBUG:onnxscript:Converter:_translate_function_def_common:reshape_to_2d
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_bind:shape
# DEBUG:onnxscript:Converter:_bind:rank
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:reshape_to_2d
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_atleast_2d_sequence' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_atleast_3d' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_atleast_3d_sequence
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'ast.FunctionDef'>
# DEBUG:onnxscript:Converter:_translate_function_def_common:reshape_to_3d
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_bind:shape
# DEBUG:onnxscript:Converter:_bind:rank
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:tensor
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:reshape_to_3d
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_atleast_3d_sequence' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_baddbmm' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bernoulli' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_bernoulli_p
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:p
# DEBUG:onnxscript:Converter:_bind:self_float
# DEBUG:onnxscript:Converter:_bind:rands
# DEBUG:onnxscript:Converter:_bind:sampled
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bernoulli_p' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bilinear' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bincount' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_and' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_and_scalar' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_and_scalar_tensor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_left_shift' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_left_shift_tensor_scalar' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_left_shift_scalar_tensor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_not' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_or' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_or_scalar' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_or_scalar_tensor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_right_shift' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_right_shift_tensor_scalar' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_right_shift_scalar_tensor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_xor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_xor_scalar' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bitwise_xor_scalar_tensor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_blackman_window' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_bmm' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_broadcast_to' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_cat_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_cat' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_ceil' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'python_math_ceil' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_chunk' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_clamp' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_clamp_tensor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_clamp_max' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_clamp_max_tensor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_clamp_min' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_clamp_min_tensor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_clone' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_clone_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_conj' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_conj_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_constant_pad_nd' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_contiguous' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_conv1d' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_conv1d_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_conv2d' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_conv2d_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_conv3d' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_conv3d_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_convolution' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_copy' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten__to_copy' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_cos' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_cosh' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_cross
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:dim
# DEBUG:onnxscript:Converter:_bind:a1
# DEBUG:onnxscript:Converter:_bind:a2
# DEBUG:onnxscript:Converter:_bind:a3
# DEBUG:onnxscript:Converter:_bind:b1
# DEBUG:onnxscript:Converter:_bind:b2
# DEBUG:onnxscript:Converter:_bind:b3
# DEBUG:onnxscript:Converter:_bind:c1
# DEBUG:onnxscript:Converter:_bind:c2
# DEBUG:onnxscript:Converter:_bind:c3
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_cross' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_cumsum' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_deg2rad' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_detach' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_diagonal' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_div' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'operator_truediv' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_div_complex
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self_real
# DEBUG:onnxscript:Converter:_bind:self_imag
# DEBUG:onnxscript:Converter:_bind:other_real
# DEBUG:onnxscript:Converter:_bind:other_imag
# DEBUG:onnxscript:Converter:_bind:ac
# DEBUG:onnxscript:Converter:_bind:bd
# DEBUG:onnxscript:Converter:_bind:bc
# DEBUG:onnxscript:Converter:_bind:ad
# DEBUG:onnxscript:Converter:_bind:denominator
# DEBUG:onnxscript:Converter:_bind:real
# DEBUG:onnxscript:Converter:_bind:imag
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_div_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_div_mode' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_dot' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_dropout' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_einsum' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_embedding' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_embedding_bag' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:_aten_embedding_bag_onnx
# DEBUG:onnxscript:Converter:_bind:weight
# DEBUG:onnxscript:Converter:_bind:indices
# DEBUG:onnxscript:Converter:_bind:offsets
# DEBUG:onnxscript:Converter:_bind:mode
# DEBUG:onnxscript:Converter:_bind:per_sample_weights
# DEBUG:onnxscript:Converter:_bind:include_last_offset
# DEBUG:onnxscript:Converter:_bind:neg_1
# DEBUG:onnxscript:Converter:_bind:indices_1d
# DEBUG:onnxscript:Converter:_bind:new_weight
# DEBUG:onnxscript:Converter:_bind:new_weight
# DEBUG:onnxscript:Converter:_bind:weight_dim_1
# DEBUG:onnxscript:Converter:_bind:indices_size
# DEBUG:onnxscript:Converter:_bind:num_bag
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:num_bag
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:offsets
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:num_bag
# DEBUG:onnxscript:Converter:_bind:offsets
# DEBUG:onnxscript:Converter:_bind:new_weight
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:index_tensor
# DEBUG:onnxscript:Converter:_bind:cond
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'ast.While'>
# DEBUG:onnxscript:Converter:_bind:infinite_loop
# DEBUG:onnxscript:Converter:_bind:index_tensor
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:slice_index
# DEBUG:onnxscript:Converter:_bind:start
# DEBUG:onnxscript:Converter:_bind:end
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:weight_rows
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_enter_scope:5:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:weight_rows
# DEBUG:onnxscript:Converter:_enter_scope:6:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_bind:denominator
# DEBUG:onnxscript:Converter:_enter_scope:7:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:7
# DEBUG:onnxscript:Converter:_enter_scope:7:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_exit_scope:7
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:6
# DEBUG:onnxscript:Converter:_enter_scope:6:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:6
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:5
# DEBUG:onnxscript:Converter:_enter_scope:5:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_enter_scope:6:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:weight_rows
# DEBUG:onnxscript:Converter:_exit_scope:6
# DEBUG:onnxscript:Converter:_enter_scope:6:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:weight_rows
# DEBUG:onnxscript:Converter:_exit_scope:6
# DEBUG:onnxscript:Converter:_bind:weight_rows
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:5
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:index_tensor
# DEBUG:onnxscript:Converter:_bind:cond
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:index_tensor
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:dim_0
# DEBUG:onnxscript:Converter:_bind:dim_1
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op '_aten_embedding_bag_onnx' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_embedding_bag_padding_idx' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:_aten_embedding_bag_1d_padding_idx_onnx
# DEBUG:onnxscript:Converter:_bind:weight
# DEBUG:onnxscript:Converter:_bind:indices
# DEBUG:onnxscript:Converter:_bind:offsets
# DEBUG:onnxscript:Converter:_bind:mode
# DEBUG:onnxscript:Converter:_bind:per_sample_weights
# DEBUG:onnxscript:Converter:_bind:include_last_offset
# DEBUG:onnxscript:Converter:_bind:padding_idx
# DEBUG:onnxscript:Converter:_bind:neg_1
# DEBUG:onnxscript:Converter:_bind:num_embeddings
# DEBUG:onnxscript:Converter:_bind:num_embeddings_scalar
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:padding_idx
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:padding_idx
# DEBUG:onnxscript:Converter:_bind:indices_weight
# DEBUG:onnxscript:Converter:_bind:indices_weight
# DEBUG:onnxscript:Converter:_bind:indices_weight
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:num_bag
# DEBUG:onnxscript:Converter:_bind:idx_size
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:num_bag
# DEBUG:onnxscript:Converter:_bind:offsets
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:offsets
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:num_bag
# DEBUG:onnxscript:Converter:_bind:offsets
# DEBUG:onnxscript:Converter:_bind:i
# DEBUG:onnxscript:Converter:_bind:cond_1
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'ast.While'>
# DEBUG:onnxscript:Converter:_bind:infinite_loop
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:i
# DEBUG:onnxscript:Converter:_bind:start_pos
# DEBUG:onnxscript:Converter:_bind:end_pos
# DEBUG:onnxscript:Converter:_bind:curr_offsets
# DEBUG:onnxscript:Converter:_bind:j
# DEBUG:onnxscript:Converter:_bind:cond_2
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'ast.While'>
# DEBUG:onnxscript:Converter:_bind:infinite_loop
# DEBUG:onnxscript:Converter:_bind:j
# DEBUG:onnxscript:Converter:_bind:curr_offsets
# DEBUG:onnxscript:Converter:_bind:index
# DEBUG:onnxscript:Converter:_bind:normalized_index
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:normalized_index
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_bind:normalized_index
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:curr_offsets
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_bind:curr_offsets
# DEBUG:onnxscript:Converter:_bind:j
# DEBUG:onnxscript:Converter:_bind:cond_2
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:j
# DEBUG:onnxscript:Converter:_bind:curr_offsets
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:dim_1
# DEBUG:onnxscript:Converter:_bind:expand_shape
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:row_weight
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_enter_scope:4:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_enter_scope:5:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:5
# DEBUG:onnxscript:Converter:_enter_scope:5:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:5
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:4
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:row_result
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:i
# DEBUG:onnxscript:Converter:_bind:cond_1
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:i
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_enter_scope:3:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:dim_0
# DEBUG:onnxscript:Converter:_bind:dim_1
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:3
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:bag_size
# DEBUG:onnxscript:Converter:_bind:offset2bag
# DEBUG:onnxscript:Converter:_bind:max_indices
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op '_aten_embedding_bag_1d_padding_idx_onnx' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_embedding_renorm' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_empty' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_empty_like' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_empty_strided' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_eq' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_equal' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_exp' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_exp2' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_expand' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_expand_as' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_fake_quantize_per_channel_affine' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_fake_quantize_per_tensor_affine' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_fake_quantize_per_tensor_affine_tensor_qparams' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_fill
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:value
# DEBUG:onnxscript:Converter:_bind:value
# DEBUG:onnxscript:Converter:_bind:shape
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_fill' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_flatten' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_flip' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_flip_complex' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_floor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'python_math_floor' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_floor_divide' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'operator_floordiv' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_fmod' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_frac' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_full' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_full_like' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_gather' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_ge' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'operator_ge' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_gru' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_getitem
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:i
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_getitem' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_grid_sampler' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_grid_sampler_2d' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_grouped_mm' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_gt' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'operator_gt' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_hamming_window' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_hann_window' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_heaviside' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_histc' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_index' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_index_put' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_index_select' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_instance_norm' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_is_nonzero
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_enter_scope:2:node:<class 'NoneType'>
# DEBUG:onnxscript:Converter:_exit_scope:2
# DEBUG:onnxscript:Converter:_bind:result
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_is_nonzero' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_isclose' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_isfinite
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:not_inf
# DEBUG:onnxscript:Converter:_bind:not_nan
# DEBUG:onnxscript._internal.values:An OpSchema was not provided for Op 'aten_isfinite' and there is not one found in opset 'pkg.onnxscript.torch_lib'.
# DEBUG:onnxscript:Converter:_translate_function_def_common:aten_isinf
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# ...
# DEBUG:onnxscript:Converter:_bind:output_size
# DEBUG:onnxscript:Converter:_bind:scale_factors
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:output_size
# DEBUG:onnxscript:Converter:_bind:scales_h
# DEBUG:onnxscript:Converter:_bind:scales_w
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:output_size
# DEBUG:onnxscript:Converter:_bind:scales_d
# DEBUG:onnxscript:Converter:_bind:scales_h
# DEBUG:onnxscript:Converter:_bind:scales_w
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:output_size
# DEBUG:onnxscript:Converter:_bind:align_corners
# DEBUG:onnxscript:Converter:_bind:scales_d
# DEBUG:onnxscript:Converter:_bind:scales_h
# DEBUG:onnxscript:Converter:_bind:scales_w
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:output_size
# DEBUG:onnxscript:Converter:_bind:align_corners
# DEBUG:onnxscript:Converter:_bind:scale_factors
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:a
# DEBUG:onnxscript:Converter:_bind:shape
# DEBUG:onnxscript:Converter:_bind:broadcast_dimensions
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:a
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:a
# DEBUG:onnxscript:Converter:_bind:shape
# DEBUG:onnxscript:Converter:_bind:a
# DEBUG:onnxscript:Converter:_bind:shape
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:a
# DEBUG:onnxscript:Converter:_bind:dimensions
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:other
# DEBUG:onnxscript:Converter:_bind:inp
# DEBUG:onnxscript:Converter:_bind:dims
# DEBUG:onnxscript:Converter:_bind:output_dtype
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:a
# DEBUG:onnxscript:Converter:_bind:permutation
# DEBUG:onnxscript:Converter:_bind:inp
# DEBUG:onnxscript:Converter:_bind:dims
# DEBUG:onnxscript:Converter:_bind:correction
# DEBUG:onnxscript:Converter:_bind:output_dtype
# DEBUG:onnxscript:Converter:_bind:pred
# DEBUG:onnxscript:Converter:_bind:a
# DEBUG:onnxscript:Converter:_bind:b
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scale
# DEBUG:onnxscript:Converter:_bind:zero_point
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scale
# DEBUG:onnxscript:Converter:_bind:zero_point
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scale
# DEBUG:onnxscript:Converter:_bind:zero_point
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scale
# DEBUG:onnxscript:Converter:_bind:zero_point
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:out_dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scale
# DEBUG:onnxscript:Converter:_bind:zero_point
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:out_dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scale
# DEBUG:onnxscript:Converter:_bind:zero_point
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:out_dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scales
# DEBUG:onnxscript:Converter:_bind:zero_points
# DEBUG:onnxscript:Converter:_bind:axis
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scales
# DEBUG:onnxscript:Converter:_bind:zero_points
# DEBUG:onnxscript:Converter:_bind:axis
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scales
# DEBUG:onnxscript:Converter:_bind:zero_points
# DEBUG:onnxscript:Converter:_bind:axis
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scales
# DEBUG:onnxscript:Converter:_bind:zero_points
# DEBUG:onnxscript:Converter:_bind:axis
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:out_dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scales
# DEBUG:onnxscript:Converter:_bind:zero_points
# DEBUG:onnxscript:Converter:_bind:axis
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:out_dtype
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:scales
# DEBUG:onnxscript:Converter:_bind:zero_points
# DEBUG:onnxscript:Converter:_bind:axis
# DEBUG:onnxscript:Converter:_bind:quant_min
# DEBUG:onnxscript:Converter:_bind:quant_max
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:out_dtype
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:dim
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:self
# DEBUG:onnxscript:Converter:_bind:dim
# DEBUG:onnxscript:Converter:_bind:dtype
# DEBUG:onnxscript:Converter:_bind:boxes
# DEBUG:onnxscript:Converter:_bind:scores
# DEBUG:onnxscript:Converter:_bind:iou_threshold
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:rois
# DEBUG:onnxscript:Converter:_bind:spatial_scale
# DEBUG:onnxscript:Converter:_bind:pooled_height
# DEBUG:onnxscript:Converter:_bind:pooled_width
# DEBUG:onnxscript:Converter:_bind:sampling_ratio
# DEBUG:onnxscript:Converter:_bind:aligned
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:boxes
# DEBUG:onnxscript:Converter:_bind:output_size
# DEBUG:onnxscript:Converter:_bind:spatial_scale
# DEBUG:onnxscript:Converter:_bind:input
# DEBUG:onnxscript:Converter:_bind:weight
# DEBUG:onnxscript:Converter:_bind:offset
# DEBUG:onnxscript:Converter:_bind:mask
# DEBUG:onnxscript:Converter:_bind:bias
# DEBUG:onnxscript:Converter:_bind:stride_h
# DEBUG:onnxscript:Converter:_bind:stride_w
# DEBUG:onnxscript:Converter:_bind:pad_h
# DEBUG:onnxscript:Converter:_bind:pad_w
# DEBUG:onnxscript:Converter:_bind:dilation_h
# DEBUG:onnxscript:Converter:_bind:dilation_w
# DEBUG:onnxscript:Converter:_bind:groups
# DEBUG:onnxscript:Converter:_bind:offset_groups
# DEBUG:onnxscript:Converter:_bind:use_mask
# [torch.onnx] Obtain model graph for `Net([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `Net([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decompositions...
# /usr/lib/python3.13/copyreg.py:99: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# [torch.onnx] Run decompositions... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# DEBUG:onnx_ir.passes._pass_infra:Running the 0-th pass '<onnx_ir.passes.common.inliner.InlinePass object at 0x78659db116a0>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 1-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedFunctionsPass object at 0x78659db12510>'
# INFO:onnx_ir.passes.common.unused_removal:No unused functions to remove
# DEBUG:onnx_ir.passes._pass_infra:Running the 2-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedOpsetsPass object at 0x78659db11550>'
# WARNING:onnxscript.version_converter:The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 13).
# WARNING:onnxscript.version_converter:Failed to convert the model to the target version 13 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.13/dist-packages/onnxscript/version_converter/__init__.py", line 137, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#         func=_partial_convert_version, model=model
#     )
#   File "/usr/local/lib/python3.13/dist-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#   File "/usr/local/lib/python3.13/dist-packages/onnxscript/version_converter/__init__.py", line 132, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         proto, target_version=self.target_version
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/onnx/version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
# RuntimeError: /project/onnx/version_converter/adapters/no_previous_version.h:24: adapt: Assertion `false` failed: No Previous Version of LayerNormalization exists
# DEBUG:onnx_ir.passes._pass_infra:Running the 0-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedNodesPass object at 0x78659db13b60>'
# INFO:onnx_ir.passes.common.unused_removal:Removed 1 unused nodes
# DEBUG:onnx_ir.passes._pass_infra:Running the 1-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedFunctionsPass object at 0x78659db06210>'
# INFO:onnx_ir.passes.common.unused_removal:No unused functions to remove
# DEBUG:onnx_ir.passes._pass_infra:Running the 2-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedOpsetsPass object at 0x78659db06350>'
# [torch.onnx] Optimize the ONNX graph...
# DEBUG:onnx_ir.passes._pass_infra:Running the 0-th pass '<onnx_ir.passes.common.inliner.InlinePass object at 0x78659db04690>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 1-th pass '<onnx_ir.passes.PassManager object at 0x78659db10440>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 0-th pass '<onnxscript.optimizer._constant_folding.FoldConstantsPass object at 0x78659dd68830>'
# DEBUG:onnxscript.optimizer._constant_folding:Skipping constant folding for Constant node 'node_Constant_1'
# DEBUG:onnxscript.optimizer._constant_folding:Skipping constant folding for Constant node 'node_Constant_2'
# DEBUG:onnxscript.optimizer._constant_folding:Evaluating ::Concat
# DEBUG:onnxscript.optimizer._constant_folding:New Initializer for value val_3 dtype: int64 shape: (2,)
# DEBUG:onnxscript.optimizer._constant_folding:Replacing node: ::Concat node_Concat_3
# INFO:onnxscript.optimizer._constant_folding:Skipping constant folding for node 'node_view' because it is graph input to preserve graph signature
# DEBUG:onnx_ir.passes._pass_infra:Running the 1-th pass '<onnxscript.rewriter.RewritePass object at 0x78659db13b60>'
# INFO:onnx_ir.passes.common.unused_removal:Removed 2 unused nodes
# DEBUG:onnx_ir.passes._pass_infra:Running the 2-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedNodesPass object at 0x78659db06210>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 3-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedFunctionsPass object at 0x78659db06350>'
# INFO:onnx_ir.passes.common.unused_removal:No unused functions to remove
# DEBUG:onnx_ir.passes._pass_infra:Running the 4-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedOpsetsPass object at 0x78659db05810>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 0-th pass '<onnxscript.optimizer._constant_folding.FoldConstantsPass object at 0x78659dd68830>'
# INFO:onnxscript.optimizer._constant_folding:Skipping constant folding for node 'node_view' because it is graph input to preserve graph signature
# DEBUG:onnx_ir.passes._pass_infra:Running the 1-th pass '<onnxscript.rewriter.RewritePass object at 0x78659db13b60>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 2-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedNodesPass object at 0x78659db06210>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 3-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedFunctionsPass object at 0x78659db06350>'
# INFO:onnx_ir.passes.common.unused_removal:No unused functions to remove
# DEBUG:onnx_ir.passes._pass_infra:Running the 4-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedOpsetsPass object at 0x78659db05810>'
# INFO:onnx_ir.passes._pass_infra:PassManager: No more graph changes detected after step 1
# DEBUG:onnx_ir.passes._pass_infra:Running the 2-th pass '<onnx_ir.passes.common.unused_removal.RemoveUnusedNodesPass object at 0x78659db06490>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 3-th pass '<onnx_ir.passes.common.constant_manipulation.LiftConstantsToInitializersPass object at 0x78659db11940>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 4-th pass '<onnx_ir.passes.common.constant_manipulation.LiftSubgraphInitializersToMainGraphPass object at 0x78659db116a0>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 5-th pass '<onnx_ir.passes.common.initializer_deduplication.DeduplicateInitializersPass object at 0x78659db12510>'
# DEBUG:onnx_ir.passes.common.initializer_deduplication:Skipped initializer 'layer1.weight' as it exceeds the size limit of 1024 elements
# DEBUG:onnx_ir.passes._pass_infra:Running the 6-th pass '<onnx_ir.passes.common.common_subexpression_elimination.CommonSubexpressionEliminationPass object at 0x78659db11550>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 7-th pass '<onnx_ir.passes.common.output_fix.OutputFixPass object at 0x78659db10830>'
# DEBUG:onnx_ir.passes._pass_infra:Running the 8-th pass '<onnx_ir.passes.common.naming.NameFixPass object at 0x78659db112b0>'
# [torch.onnx] Optimize the ONNX graph... ✅
# Traceback (most recent call last):
#   File "/content/openwakeword/openwakeword/train.py", line 909, in <module>
#     convert_onnx_to_tflite(os.path.join(config["output_dir"], config["model_name"] + ".onnx"),
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                            os.path.join(config["output_dir"], config["model_name"] + ".tflite"))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/openwakeword/openwakeword/train.py", line 578, in convert_onnx_to_tflite
#     from onnx_tf.backend import prepare
# ModuleNotFoundError: No module named 'onnx_tf'

# %%
import os
path = "/content/my_custom_model/hey_sebastian.onnx"
print("Ada:", os.path.exists(path))
print("Ukuran:", os.path.getsize(path) if os.path.exists(path) else "-")
# Out:
# Ada: True
# Ukuran: 13822

# %%
# Step 4 (Optional): On Google Colab, sometimes the .tflite model isn't saved correctly
# If so, run this cell to retry

# Manually save to tflite as this doesn't work right in colab
def convert_onnx_to_tflite(onnx_model_path, output_path):
    """Converts an ONNX version of an openwakeword model to the Tensorflow tflite format."""
    # imports
    import onnx
    import logging
    import tempfile
    from onnx_tf.backend import prepare
    import tensorflow as tf

    # Convert to tflite from onnx model
    onnx_model = onnx.load(onnx_model_path)
    tf_rep = prepare(onnx_model, device="CPU")
    with tempfile.TemporaryDirectory() as tmp_dir:
        tf_rep.export_graph(os.path.join(tmp_dir, "tf_model"))
        converter = tf.lite.TFLiteConverter.from_saved_model(os.path.join(tmp_dir, "tf_model"))
        tflite_model = converter.convert()

        logging.info(f"####\nSaving tflite mode to '{output_path}'")
        with open(output_path, 'wb') as f:
            f.write(tflite_model)

    return None

convert_onnx_to_tflite(f"my_custom_model/{config['model_name']}.onnx", f"my_custom_model/{config['model_name']}.tflite")

# %% [markdown]
# After the model finishes training, the auto training script will automatically convert it to ONNX and tflite versions, saving them as `my_custom_model/<model_name>.onnx/tflite` in the present working directory, where `<model_name>` is defined in the YAML training config file. Either version can be used as normal with `openwakeword`. I recommend testing them with the [`detect_from_microphone.py`](https://github.com/dscripka/openWakeWord/blob/main/examples/detect_from_microphone.py) example script to see how the model performs!
